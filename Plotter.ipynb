# %%
from plot_utils import *
import os
import json
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Vanilla Training

# %%
nocur_folder = "output/dog_fight_SAC"
cur_folder = "output/dog_fight_SAC"
level_list = ["level1", "level2"]    
scenario = "dog_fight"
map_folder = "saved_figs/" + scenario
if not os.path.exists(map_folder):
    os.makedirs(map_folder)
show_both_approaches(level_list=level_list, curriculum_folder = cur_folder, N_interval=10)
