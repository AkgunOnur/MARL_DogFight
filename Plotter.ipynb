# %%
from plot_utils import *
import os
import json
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Vanilla Training

# %%
nocur_folder = "output/outputs_moving_target/"
# level_list = ["easy", "medium", "target"]  
level_list = ["level1", "level2", "level3", "level4", "level5"]    
scenario = "moving_target"
map_folder = "saved_figs/" + scenario
if not os.path.exists(map_folder):
    os.makedirs(map_folder)
show_both_approaches(level_list=level_list, scenario=scenario, nocurriculum_folder = nocur_folder, N_interval=10)
